# %%
import os
cwd = os.getcwd()
print(cwd)

filename = '/home/saanviperi/pride and prejudice.txt'
try:
    with open(filename, 'r', encoding = 'utf8') as h:
        htext = h.read() 
except e:
    print(f"No such file, {filename}")
from collections import Counter #collections are already installed
count = Counter(htext.split()) #pass to Counter your frequency dict
count.most_common(50)
# Out:
# /home/saanviperi
# [('the', 4216),
#  ('to', 4123),
#  ('of', 3667),
#  ('and', 3309),
#  ('a', 1944),
#  ('her', 1856),
#  ('in', 1817),
#  ('was', 1796),
#  ('I', 1725),
#  ('that', 1417),
#  ('not', 1363),
#  ('she', 1303),
#  ('be', 1209),
#  ('his', 1166),
#  ('had', 1125),
#  ('as', 1119),
#  ('with', 1040),
#  ('he', 1039),
#  ('for', 1003),
#  ('you', 992),
#  ('it', 952),
#  ('have', 818),
#  ('is', 803),
#  ('Mr.', 766),
#  ('at', 749),
#  ('on', 648),
#  ('by', 636),
#  ('but', 608),
#  ('my', 580),
#  ('were', 544),
#  ('all', 529),
#  ('so', 519),
#  ('which', 509),
#  ('him', 500),
#  ('been', 499),
#  ('could', 496),
#  ('from', 480),
#  ('they', 472),
#  ('very', 467),
#  ('would', 457),
#  ('no', 428),
#  ('their', 406),
#  ('your', 399),
#  ('Elizabeth', 398),
#  ('will', 388),
#  ('what', 384),
#  ('such', 370),
#  ('this', 361),
#  ('or', 357),
#  ('an', 350)]

# %%
from collections import Counter #collections are already installed
count = Counter(filter(lambda x: len(x) > 5, htext.split())) #pass to Counter your frequency dict
count.most_common(20)
# Out:
# [('Elizabeth', 398),
#  ('should', 244),
#  ('though', 196),
#  ('without', 172),
#  ('Bennet', 168),
#  ('little', 165),
#  ('before', 164),
#  ('Bingley', 149),
#  ('nothing', 143),
#  ('Elizabeth,', 136),
#  ('herself', 127),
#  ('Chapter', 122),
#  ('always', 116),
#  ('cannot', 112),
#  ('however,', 112),
#  ('Collins', 100),
#  ('thought', 97),
#  ('Darcy,', 96),
#  ('sister', 90),
#  ('Bennet,', 89)]

# %%
counter = Counter(filter(lambda x: x != lst, htext.split()))
lst = [
'i',
'I',
'me',
'my', 
'myself', 
'we', 
'our',
'ours',
'ourselves',
'you', 
'your',
'yours', 
'yourself', 
'yourselves', 
'he',                      
'him',
'his',
'himself',
'she',
'her',
'hers',
'herself',
'it',
'its',
'itself',
'they',
'them',
'their',
'theirs',
'themselves',
'what',
'which',
'who',
'whom',
'this',
'that',
'these',
'those',
'am',
'is',
'are',
'was',
'were',
'be',
'been',
'being',
'have',
'has',
'had',
'having',
'do',
'does',
'did',
'doing',
'a',
'an',
'the',
'and',
'but',
'if',
'or',
'because',
'as',
'until',
'while',
'of',
'at',
'by',
'for',
'with',
'about',
'against',
'between',
'into',
'through',
'during',
'before',
'after',
'above',
'below',
'to',
'from',
'up',
'down',
'in',
'out',
'on',
'off',
'over',
'under',
'again',
'further',
'then',
'once',
'here',
'there',
'when',
'where',
'why',
'how',
'all',
'any',
'both',
'each',
'few',
'more',
'most',
'other',
'some',
'such',
'no',
'nor',
'not',
'only',
'own',
'same',
'so',
'than',
'too',
'very',
's',
't',
'can',
'will',
'just',
'dont',
'should']
count.most_common(20)
# Out:
# [('Elizabeth', 398),
#  ('should', 244),
#  ('though', 196),
#  ('without', 172),
#  ('Bennet', 168),
#  ('little', 165),
#  ('before', 164),
#  ('Bingley', 149),
#  ('nothing', 143),
#  ('Elizabeth,', 136),
#  ('herself', 127),
#  ('Chapter', 122),
#  ('always', 116),
#  ('cannot', 112),
#  ('however,', 112),
#  ('Collins', 100),
#  ('thought', 97),
#  ('Darcy,', 96),
#  ('sister', 90),
#  ('Bennet,', 89)]
