# %%
import numpy as np

import matplotlib.pyplot as plt

import time

time.time()

import time
start = time.process_time()

x = np.arange(-20,21)

y = [i**2 for i in x]

import matplotlib.pyplot as plt
plt.plot(y)

print(time.process_time() - start)

start = time.process_time()

np.array(y)

print(time.process_time() - start)

print("The list is faster.")

z = np.random.randint(0,101, 20)

print(z)

result = list(filter(lambda x: (x % 2 == 1), z)) 
print(f"This is the list of odd numbers: {result}")

class Vehicle():
    def __init__(self, name, year, public):
        self.name = name
        self.year = year
        self.public = public
        
    def intro(self):
        return(f"The brand of the vehicle is {self.name} , the year it was made is {self.year} and it is a {self.public} form of transportation.")

class Bus(Vehicle):
    def __init__(self, name, year, public, capacity, rate):
        super().__init__(name, year, public)
        self.capacity = capacity
        self.rate = rate
        
    def is_full(num_people_waiting):
        if num_people_waiting > capacity:
            return True
        else:
            return False
    
    def next_bus(day):
        if day == 'Monday' or 'Tuesday' or 'Wednesday' or 'Thursday' or 'Friday':
            print(f"The bus will arrive in {self.rate} minutes or less.")
        elif day == 'Saturday' or 'Sunday':
            print(f"The bus will arrive in {int(self.rate)*2} minutes or less.")

class Car(Vehicle):
    def __init__(self, name, year, public, milage, max_speed):
        super().__init__(name, year, public)
        self.milage = milage
        self.max_speed = max_speed
    
    def is_a_race_car():
        if self.milage < 100000 and self.max_speed > 150:
            print('yes')
        
the_vehicle = Vehicle('Tesla','2018','private')
the_vehicle.intro()
# Out:
# 0.09155913900000101
# 0.0002420550000010735
# The list is faster.
# [26  3 79 33 42  1 40 16 51 76 41 53 83  8 12 26 84 31 70 51]
# This is the list of odd numbers: [3, 79, 33, 1, 51, 41, 53, 83, 31, 51]
# 'The brand of the vehicle is Tesla , the year it was made is 2018 and it is a private form of transportation.'

# %%
import os
cwd = os.getcwd()
print(cwd)

filename = '/home/saanviperi/wonderful wizard of oz.txt'
try:
    with open(filename, 'r', encoding = 'utf8') as h:
        htext = h.read() 
except e:
    print(f"No such file, {filename}")

print("_" * 80)
#print(htext)
len_txt = len(htext)
num_words = htext.count(' ')
num_sens = htext.count('.')
file = []
file.append(f"Number of characters: {len_txt}")
file.append(f"Number of words: {num_words}") # default - split by space
file.append(f"Number of sentences: {num_sens}")
print(file)

from collections import Counter
lst = [
'i',
'I',
'me',
'my', 
'myself', 
'we', 
'our',
'ours',
'ourselves',
'you', 
'your',
'yours', 
'yourself', 
'yourselves', 
'he',                      
'him',
'his',
'himself',
'she',
'her',
'hers',
'herself',
'it',
'its',
'itself',
'they',
'them',
'their',
'theirs',
'themselves',
'what',
'which',
'who',
'whom',
'this',
'that',
'these',
'those',
'am',
'is',
'are',
'was',
'were',
'be',
'been',
'being',
'have',
'has',
'had',
'having',
'do',
'does',
'did',
'doing',
'a',
'an',
'the',
'and',
'but',
'if',
'or',
'because',
'as',
'until',
'while',
'of',
'at',
'by',
'for',
'with',
'about',
'against',
'between',
'into',
'through',
'during',
'before',
'after',
'above',
'below',
'to',
'from',
'up',
'down',
'in',
'out',
'on',
'off',
'over',
'under',
'again',
'further',
'then',
'once',
'here',
'there',
'when',
'where',
'why',
'how',
'all',
'any',
'both',
'each',
'few',
'more',
'most',
'other',
'some',
'such',
'no',
'nor',
'not',
'only',
'own',
'same',
'so',
'than',
'too',
'very',
's',
't',
'can',
'will',
'just',
'dont',
'should']

new_htext = htext.lower()
counter = Counter(filter(lambda x: x != lst, new_htext.split()))
print(counter)
# Out:
# /home/saanviperi
# ________________________________________________________________________________
# ['Number of characters: 227191', 'Number of words: 39002', 'Number of sentences: 2188']
# ...
